# %% [markdown]
# # NMR Experiment

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import pandas as pd
import seaborn as sb
from numpy import polyfit
import scipy.constants as const

# %%
def linearfit(x, a, b):
    return a*x + b

# %% [markdown]
# ## Calibration

# %%
datasub = pd.read_excel('NMR.xlsx', sheet_name='calibration')
datasub.head()
# Out:
#    B in mT  I in A
# 0     10.7    0.05
# 1     64.6    0.49
# 2    130.5    1.00
# 3    197.5    1.50
# 4    264.0    2.00

# %%
isub = datasub['I in A'].to_numpy()
bsub = datasub['B in mT'].to_numpy()

pfit = polyfit(isub, bsub, 7)
dg = pfit.size-1
isubfit = np.linspace(isub.min(), isub.max(), 100)
print(f'parameters: {pfit}')
cal1, cal0 = pfit[0], pfit[1]
calfn = lambda x: sum([pfit.T[i]*x**(dg-i) for i in range(dg+1)])
bsubfit = calfn(isubfit)
sb.scatterplot(data=datasub, x='I in A', y='B in mT')
plt.plot(isubfit, bsubfit, 'orange')
plt.title('Calibration curve for Magnetic field vs. Current')
plt.grid()
plt.savefig('nmr_cal', dpi=600)
plt.show()
# Out:
# parameters: [-3.83780292e-02  6.64576986e-01 -4.32282998e+00  1.33491247e+01
#  -2.39136720e+01  2.83542869e+01  1.11642785e+02  5.08354964e+00]

# %% [markdown]
# ## 1. Glycerine

# %%
df1 = pd.read_excel('NMR.xlsx', sheet_name='glycerine')
display(df1.head())
Ivals = df1['I in A'].to_numpy()
fvals = df1['freq in MHz'].to_numpy()
delf1 = df1['del f FWHM'].to_numpy()
Bvals = calfn(Ivals)
xsub, ysub = Bvals, fvals
# Out:
#    I in A  freq in MHz  del X FWHM     Y      Y/rt2  del f FWHM  Unnamed: 6  \
# 0    3.11      17.5080         360  75.0  53.033009    0.080113         NaN
# 1    3.26      18.1430         400  59.6  42.143564    0.089014         NaN
# 2    3.38      18.5619         320  56.4  39.880822    0.071211         NaN
# 3    3.57      19.1758         400  48.0  33.941125    0.089014         NaN
# 4    3.74      19.6521         520  43.2  30.547013    0.115718         NaN
#
#              x1       -240
# 0            f1  19.622300
# 1            x2   1.760000
# 2            f2  19.676100
# 3  del f/ del x   0.000223
# 4           NaN        NaN

# %%
popt, pcov = curve_fit(linearfit, xsub, ysub, p0=[0.05, 2])
xsubfit = np.linspace(xsub.min(), xsub.max(), 100)
ysubfit = popt[0]*xsubfit + popt[1]
print(f'slope={popt[0]} and intercept={popt[1]}')
gl1, gl0 = popt[0]*1e9, popt[1]*1e6
plt.plot(xsub, ysub, 'o', ms=4)
plt.plot(xsubfit, ysubfit, label=
        f'slope = {gl1:.5} Hz/T\nintercept = {gl0:.5} Hz')
plt.title('Resonance frequency vs. Magnetic field plot for Glycerine\n')
plt.xlabel('\nMagnetic field B (in mT)')
plt.ylabel('Resonance frequency (in MHz)\n')
plt.legend(loc='best')
plt.grid()
plt.savefig('nmr_1', dpi=600)
plt.show()
# Out:
# slope=0.04174298172091752 and intercept=1.1899935496371123

# %% [markdown]
# ## 2 Polystyrene

# %%
df1 = pd.read_excel('NMR.xlsx', sheet_name='polystyrene')
display(df1.head())
Ivals = df1['I in A'].to_numpy()
fvals = df1['freq in MHz'].to_numpy()
delf2 = df1['del f FWHM'].to_numpy()
Bvals = calfn(Ivals)
xsub, ysub = Bvals, fvals
# Out:
#    I in A  freq in MHz  del X FWHM     Y      Y/rt2  del f FWHM  Unnamed: 6  \
# 0    3.15      17.6405         640  56.0  39.597980    0.306326         NaN
# 1    3.30      18.0398         600  44.4  31.395541    0.287180         NaN
# 2    3.45      18.6193         520  35.6  25.173001    0.248890         NaN
# 3    3.60      19.2226         640  31.2  22.061732    0.306326         NaN
# 4    3.75      19.6473         720  31.6  22.344574    0.344616         NaN
#
#              x1       -2.24
# 0            f1   18.068200
# 1            x2 -240.000000
# 2            f2   18.182000
# 3  del f/ del x    0.000479
# 4           NaN         NaN

# %%
popt, pcov = curve_fit(linearfit, xsub, ysub, p0=[0.05, 2])
xsubfit = np.linspace(xsub.min(), xsub.max(), 100)
ysubfit = popt[0]*xsubfit + popt[1]
print(f'slope={popt[0]} and intercept={popt[1]}')
pl1, pl0 = popt[0]*1e9, popt[1]*1e6
plt.plot(xsub, ysub, 'o', ms=4)
plt.plot(xsubfit, ysubfit, label=
        f'slope = {pl1:.5} Hz/T\nintercept = {pl0:.5} Hz')
plt.title('Resonance frequency vs. Magnetic field plot for Polystyrene\n')
plt.xlabel('\nMagnetic field B (in mT)')
plt.ylabel('Resonance frequency (in MHz)\n')
plt.legend(loc='best')
plt.grid()
plt.savefig('nmr_2', dpi=600)
plt.show()
# Out:
# slope=0.04317555988208843 and intercept=0.48088072176479213

# %% [markdown]
# ## 3 Polytetrafluoroethylene

# %%
df1 = pd.read_excel('NMR.xlsx', sheet_name='polytetrafluoroethylene')
display(df1.head())
Ivals = df1['I in A'].to_numpy()
fvals = df1['freq in MHz'].to_numpy()
delf3 = df1['del f FWHM'].to_numpy()
Bvals = calfn(Ivals)
xsub, ysub = Bvals, fvals
# Out:
#    I in A  freq in MHz  del X FWHM in mV  Y in mV       Y/rt2  del f FWHM  \
# 0    3.25      16.9826               360    190.0  134.350288       15.21
# 1    3.40      17.3982               320    110.0   77.781746       13.52
# 2    3.55      17.8879               440     81.0   57.275649       18.59
# 3    3.70      18.2681               560     68.4   48.366104       23.66
# 4    3.85      18.7505               440     51.2   36.203867       18.59
#
#    Unnamed: 6            x1     -2.24  in V
# 0         NaN            f1  17.33930   NaN
# 1         NaN            x2   3.76000  in V
# 2         NaN            f2  17.59280   NaN
# 3         NaN  del f/ del x   0.04225   NaN
# 4         NaN           NaN       NaN   NaN

# %%
popt, pcov = curve_fit(linearfit, xsub, ysub, p0=[0.05, 2])
xsubfit = np.linspace(xsub.min(), xsub.max(), 100)
ysubfit = popt[0]*xsubfit + popt[1]
print(f'slope={popt[0]} and intercept={popt[1]}')
tf1, tf0 = popt[0]*1e9, popt[1]*1e6
plt.plot(xsub, ysub, 'o', ms=4)
plt.plot(xsubfit, ysubfit, label=
        f'slope = {tf1:.5} Hz/T\nintercept = {tf0:.5} Hz')
plt.title('Resonance frequency vs. Magnetic field plot for Teflon\n')
plt.xlabel('\nMagnetic field B (in mT)')
plt.ylabel('Resonance frequency (in MHz)\n')
plt.legend(loc='best')
plt.grid()
plt.savefig('nmr_3', dpi=600)
plt.show()
# Out:
# slope=0.038747564019565424 and intercept=1.2644206332912893

# %% [markdown]
# ## Calculations

# %% [markdown]
# ### g factor
# $$g = \frac{h}{\mu_n} \frac{\nu}{B}$$

# %%
h = const.h
mu_n = 5.051e-27
print(f'h = {h}, mu_n = {mu_n}')
# Out:
# h = 6.62607015e-34, mu_n = 5.051e-27

# %%
g1 = (h/mu_n)*(gl1)
print(f'g factor for glycerine = {g1}.')
g2 = (h/mu_n)*(pl1)
print(f'g factor for polystyrene = {g2}.')
g3 = (h/mu_n)*(tf1)
print(f'g factor for teflon = {g3}.')
# Out:
# g factor for glycerine = 5.4759834716485285.
# g factor for polystyrene = 5.663913849618762.
# g factor for teflon = 5.083034593847882.

# %% [markdown]
# ### Linewidth

# %%
lw1 = np.mean(delf1*1e6)
print(f'Linewidth for glycerine: {lw1:.5} Hz')
lw2 = np.mean(delf2*1e6)
print(f'Linewidth for polystyrene: {lw2:.5} Hz')
lw3 = np.mean(delf3*1e6)
print(f'Linewidth for teflon: {lw3:.5} Hz')
# Out:
# Linewidth for glycerine: 8.9014e+04 Hz
# Linewidth for polystyrene: 2.9867e+05 Hz
# Linewidth for teflon: 1.7914e+07 Hz

# %% [markdown]
# ## Error Analysis

# %% [markdown]
# ### g factor for Hydrogen
# $$g_{H} = \frac{g_{glycerine}+g_{polystyrene}}{2}$$

# %%
gHth = 5.5867
gH = (g1+g2)/2
err = abs(gHth-gH)*100/gHth
print(f'Theoretical value = {gHth}')
print(f'Calculated value = {gH}')
print(f'percentage error = {err} %')
# Out:
# Theoretical value = 5.5867
# Calculated value = 5.569948660633646
# percentage error = 0.2998431876842278 %

# %% [markdown]
# ### g factor for Fluorine
# $$g_{F} = g_{teflon}$$

# %%
gFth = 5.2567
gF = g3
err = abs(gFth-gF)*100/gFth
print(f'Theoretical value = {gFth}')
print(f'Calculated value = {gF}')
print(f'percentage error = {err} %')
# Out:
# Theoretical value = 5.2567
# Calculated value = 5.083034593847882
# percentage error = 3.303696352314547 %
